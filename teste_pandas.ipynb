# %%
import pandas as pd

# %%
tf_data=pd.read_csv("datasets/csv/AUDUSD_M1.csv")

# %%
for index in tf_data.index.values:
    print(tf_data.loc[index])
# Out:
# 2003.08.04    2003.08.04
# 00:00              00:01
# 0.65122          0.65146
# 0.65157          0.65155
# 0.6512           0.65115
# 0.65157.1        0.65149
# 50                   248
# Name: 0, dtype: object
# 2003.08.04    2003.08.04
# 00:00              00:02
# 0.65122           0.6515
# 0.65157          0.65156
# 0.6512           0.65125
# 0.65157.1         0.6515
# 50                    94
# Name: 1, dtype: object
# 2003.08.04    2003.08.04
# 00:00              00:03
# 0.65122          0.65143
# 0.65157          0.65149
# 0.6512           0.65129
# 0.65157.1        0.65139
# 50                   588
# Name: 2, dtype: object
# 2003.08.04    2003.08.04
# 00:00              00:04
# 0.65122           0.6514
# 0.65157          0.65159
# 0.6512           0.65118
# 0.65157.1        0.65118
# 50                   126
# Name: 3, dtype: object
# 2003.08.04    2003.08.04
# 00:00              00:05
# 0.65122          0.65132
# 0.65157           0.6516
# 0.6512           0.65119
# ...
